# %%
str = input("Enter a String To Calculte Length")
print(len(str))

# %%
str = "Ravitheja Ediga"
print(str.lower())
print(str.upper())
# Out:
# ravitheja ediga
# RAVITHEJA EDIGA

# %%
str="https://jupyter.org/try-jupyter/lab/index.html"
count=0
for i in str:
    if i in "aeiou" or i in "AEIOU":
        count=count+1
print(count)
# Out:
# 8

# %%
originalString = input("Enter a String To See Palindrom or Not :")
reversedString = originalString[::-1]
if originalString == reversedString:
    print('Given String Is Paliondrome ')
else:
    print('Given String Is Not Paliondrome ')
# Out:
# Enter a String To See Palindrom or Not : madam
# Given String Is Paliondrome

# %%
str = "https: //ju pyter.or  g/try-jup yte  r/notebooks/?  path=noteboo ks/In tro .ipynb" 
print(str.replace(" ","_"))
# Out:
# https:_//ju_pyter.or__g/try-jup_yte__r/notebooks/?__path=noteboo_ks/In_tro_.ipynb

# %%
str = input("Enter a String To reverse That")
l = len(str)
print(l)
newstring = ""
for i in range(0,l):
    newstring=newstring+str[l-i-1]
print(newstring)
# Out:
# Enter a String To reverse That Data Engineering
# 16
# gnireenignE ataD

# %%
str = "  Learning Python is simple and Python is powerfull "
afterremovingSpaces=str.strip()
print(afterremovingSpaces)
# Out:
# Learning Python is simple and Python is powerfull

# %%
str = "Learning Python is simple and Python is powerfull"
character = input("enter Character to find is it start with or not :")
print(str.startswith(character))
# Out:
# enter Character to find is it start with or not : L
# True

# %%
str = "Learning Python is simple and Python is powerfull"
character = input("enter Character to find its index :")
print(str.find(character))
# Out:
# enter Character to find its index : L
# 0

# %%
str = "Learning Python is simple and Python is powerfull Python"
stringToCount = input("enter a string to find its Occurence :")
print(str.count(stringToCount))
# Out:
# enter a string to find its Occurence : Python
# 2

# %%
str = "Learning Python is simple and Python is powerfull"
print(str.split())

# %%
str = "Learning Python is simple and Python is powerfull"
oldString = input("Old String To replace :")
newString = input("New String To replace :")
print(str.replace(oldString,newString))
# Out:
# Old String To replace : Python
# New String To replace : Java
# Learning Java is simple and Java is powerfull
